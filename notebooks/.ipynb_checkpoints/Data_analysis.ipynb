# %%
import sqlite3
import pandas as pd

con=sqlite3.connect('C:\\Users\\moham\\OneDrive\\Desktop\\SEM 3 OJT\\Proj_3.1\\data\\raw\\ipl.db')
def q(sql):
    return pd.read_sql(sql, con)

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script =f.read()
    con.executescript(script)
    con.commit()
    print('ran',path)

# %%
q("""
    -- what is the strike rate of every batter in the death overs

    select batter,round(100.0*sum(batter_runs)/sum(
      CASE
        when is_wide_ball=0 AND is_no_ball=0
        then 1
        else 0
      END ),2)as strike_rate

from deliveries
where over_number>=15 AND is_super_over=0
group by batter
Order by strike_rate DESC;
    """)
# Out:
#              batter  strike_rate
# 0          WG Jacks       483.33
# 1          DT Patil       400.00
# 2        KT Maphaka       400.00
# 3            L Wood       300.00
# 4          PA Reddy       300.00
# ..              ...          ...
# 637     Sunny Gupta         0.00
# 638          U Kaul         0.00
# 639  V Pratap Singh         0.00
# 640   Y Prithvi Raj         0.00
# 641      YA Abdulla         0.00
#
# [642 rows x 2 columns]

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\09_analysis_views.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\09_analysis_views.sql

# %%
q("""SELECT * 
    FROM v_ball;


""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288046       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288047       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288048       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288049       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288050       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\09_analysis_views.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\09_analysis_views.sql

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\09_analysis_views.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\09_analysis_views.sql

# %%
q("""SELECT * 
    FROM v_match_totals;""")
# Out:
#       match_id                              venue_clean city_clean  \
# 0       335982                    M Chinnaswamy Stadium  Bangalore
# 1      1082591       Rajiv Gandhi International Stadium  Hyderabad
# 2      1082592  Maharashtra Cricket Association Stadium       Pune
# 3      1082593   Saurashtra Cricket Association Stadium     Rajkot
# 4      1082594                   Holkar Cricket Stadium     Indore
# ...        ...                                      ...        ...
# 1041   1529279                   Sawai Mansingh Stadium     Jaipur
# 1042   1529280                   MA Chidambaram Stadium    Chennai
# 1043   1529282                     Arun Jaitley Stadium      Delhi
# 1044   1529284                         Wankhede Stadium     Mumbai
# 1045   1529286                   Sawai Mansingh Stadium     Jaipur
#
#       season_year result                 match_winner player_of_match  \
# 0            2008    win        Kolkata Knight Riders     BB McCullum
# ...

# %%
q("""SELECT count(*) 
    FROM v_ball group by phase""")
# Out:
#    count(*)
# 0     65488
# 1    132173
# 2     90390

# %%
q("""SELECT count(*) 
    FROM v_match_totals;""")
# Out:
#    count(*)
# 0      1046

# %%
q("""SELECT count(*) 
    FROM v_innings;""")
# Out:
#    count(*)
# 0      2418

# %%
q("""SELECT phase,count(*) 
    FROM v_ball;""")
# Out:
#        phase  count(*)
# 0  Powerplay    288051
