# %%
import sqlite3
import pandas as pd

con=sqlite3.connect('C:\\Users\\moham\\OneDrive\\Desktop\\SEM 3 OJT\\Proj_3.1\\data\\raw\\ipl.db')
def q(sql):
    return pd.read_sql(sql, con)

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script =f.read()
    con.executescript(script)
    con.commit()
    print('ran',path)

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\01_nulls_and_blanks.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\01_nulls_and_blanks.sql

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\02_merge_categories.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\02_merge_categories.sql

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\03_venue_names.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\03_venue_names.sql

# %%
q("""Select venue_clean,Count(*) AS matches
from  v_matches_venue
GROUP BY venue_clean
ORDER BY matches DESC limit 5;""")
# Out:
#                           venue_clean  matches
# 0                    Wankhede Stadium      130
# 1                        Eden Gardens      104
# 2              MA Chidambaram Stadium       95
# 3               M Chinnaswamy Stadium       89
# 4  Rajiv Gandhi International Stadium       87

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\04_dedupe_venues.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\04_dedupe_venues.sql

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\04_dedupe_venues.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\04_dedupe_venues.sql

# %%
q("""Select count (*),venue,city
from venues
Group by venue
order by count(*) DESC
limit 10;""")
# Out:
#    count (*)                                              venue       city
# 0          2                            Sharjah Cricket Stadium        NaN
# 1          2  Maharaja Yadavindra Singh International Cricke...     Mohali
# 2          2                Dubai International Cricket Stadium        NaN
# 3          2                 Dr DY Patil Sports Academy, Mumbai     Mumbai
# 4          1                   Zayed Cricket Stadium, Abu Dhabi  Abu Dhabi
# 5          1                           Wankhede Stadium, Mumbai     Mumbai
# 6          1                                   Wankhede Stadium     Mumbai
# 7          1       Vidarbha Cricket Association Stadium, Jamtha     Nagpur
# 8          1                                    SuperSport Park  Centurion
# 9          1                         Subrata Roy Sahara Stadium       Pune

# %%
q("""Select count(*)As rows,COUNT(DISTINCT venue) AS names
FROM v_venues_clean;
""")
# Out:
#    rows  names
# 0    59     59

# %%
q("""select count(*),venue,city
from v_venues_clean
group by venue
order by count(*) desc
limit 10;""")
# Out:
#    count(*)                                             venue            city
# 0         1                  Zayed Cricket Stadium, Abu Dhabi       Abu Dhabi
# 1         1                          Wankhede Stadium, Mumbai          Mumbai
# 2         1                                  Wankhede Stadium          Mumbai
# 3         1      Vidarbha Cricket Association Stadium, Jamtha          Nagpur
# 4         1                                   SuperSport Park       Centurion
# 5         1                        Subrata Roy Sahara Stadium            Pune
# 6         1                                  St George's Park  Port Elizabeth
# 7         1                              Sheikh Zayed Stadium       Abu Dhabi
# 8         1                           Sharjah Cricket Stadium         Sharjah
# 9         1  Shaheed Veer Narayan Singh International Stadium          Raipur

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\05_city_fallback.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\05_city_fallback.sql

# %%
q("""select city_clean from v_city_clean
where city_clean is null;""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q("""select city_clean from v_city_clean
where city_clean = 'UNKNOWN';""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q(""" SELECT city_clean FROM v_city_clean
WHERE city_clean IN('UNKNOWN');""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q(""" SELECT city_clean FROM v_city_clean
LIMIT 5;""")
# Out:
#   city_clean
# 0  Bangalore
# 1  Hyderabad
# 2       Pune
# 3     Rajkot
# 4     Indore

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\06_season_year.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\06_season_year.sql

# %%
q(""" select season,
         count(*) as matches
from matches
where season ='2020/21'
group by season;""")
# Out:
#     season  matches
# 0  2020/21       60

# %%
run_sql_file(
    r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\06_season_year.sql"
)

q("""
SELECT DISTINCT season, season_year
FROM v_season
WHERE season = '2020/21';
""")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\06_season_year.sql
#     season  season_year
# 0  2020/21         2020

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\07_win_definition.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\07_win_definition.sql

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\08_matches_clean.sql")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\08_matches_clean.sql

# %%
run_sql_file(r"C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\08_matches_clean.sql")

q("""SELECT * from matches_clean;""")
# Out:
# ran C:\Users\moham\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\sql\08_matches_clean.sql
#       match_id                              venue_clean city_clean  \
# 0       335982                    M Chinnaswamy Stadium  Bangalore
# 1      1082591       Rajiv Gandhi International Stadium  Hyderabad
# 2      1082592  Maharashtra Cricket Association Stadium       Pune
# 3      1082593   Saurashtra Cricket Association Stadium     Rajkot
# 4      1082594                   Holkar Cricket Stadium     Indore
# ...        ...                                      ...        ...
# 1063   1529279                   Sawai Mansingh Stadium     Jaipur
# 1064   1529280                   MA Chidambaram Stadium    Chennai
# 1065   1529282                     Arun Jaitley Stadium      Delhi
# 1066   1529284                         Wankhede Stadium     Mumbai
# 1067   1529286                   Sawai Mansingh Stadium     Jaipur
#
#       season_year result                 match_winner player_of_match  \
# ...

# %%
import ast
import pandas as pd 
d= pd.read_sql('Select * From deliveries where fielders_involved is not null', con)
d['fielders'] = d['fielders_involved'].apply(ast.literal_eval)

d=d.explode('fielders')
d['fielders'].value_counts().head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 7
#       3 d= pd.read_sql('Select * From deliveries where fielders_involved is not null', con)
#       4 d['fielders'] = d['fielders_involved'].apply(ast.literal_eval)
#       5
#       6 d=d.explode('fielders')
# ----> 7 d['fielders'].values_counts().head(5)
#
# File ~\OneDrive\Desktop\SEM 3 OJT\Proj_3.1\.venv\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'values_counts'
